# %%
import numpy as np

import matplotlib.pyplot as plt
from PIL import Image, ImageOps
# %matplotlib inline

  
# open method used to open different extension image file 
img = plt.imread('image.jpg')  
  
# This method will show image in any image viewer  
plt.imshow(img)

# %%
img_pil = Image.fromarray(np.uint8(img))
img_pil = ImageOps.equalize(img_pil)
plt.imshow(img_pil)

# %%
plt.hist(img.ravel())
# Out:
# (array([520680.,  90453.,  72132.,  37158.,  13332.,  13554.,  11667.,
#           9552.,   8532.,   9372.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
img2 = np.asarray(img_pil)
plt.hist(img2.ravel())
# Out:
# (array([221274.,      0.,  49440.,  42045.,  80193.,  78753.,  80406.,
#          77283.,  78510.,  78528.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
img2 = img2[::-1]
plt.imshow(img2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-7b4fb1986960> in <module>
# ----> 1 img2[256:512] = img2[-256:-1]
#       2 plt.imshow(img2)
#
# ValueError: assignment destination is read-only
